# %%
user_info={"user_name":"","pin":"","balance":20000,"transaction_info":[],}
        
def register():
        print("\n--- Register ---")
        user_info["username"] = input("Enter a username: ")
        user_info["pin"] = input("Create your password: \n")
        print("Registration is successful! you have received MK20230 as innitial amount in your account.")

def sign_in():
    
        user_name = input("Enter your username: ")
        user_password = input("Enter your password: ")
        if username == user_info["username"] and password == user_info["password"]:
            print("Sign in  is now successful!")
            return True
        else:
            print("Invalid username or password.")
                
def check_balance():
        print("\n---check_balance---")
        check_balance()
        amount=1000
        account_number=2021
        name=input("enter username:")
        number=input("enter the account number to get your balance:")
        if account_number ==number:
            print("dear customer your current balance in your account is[amount]")
def send_money_To_():
    
        print("\n--- Send Money---")
        print("1. Own Account")
        print("2.  Nation Bank Account")
        print("3.  Mobile Wallet")
        choice = input("Choose an option (1-3): ")

        amount = float(input("Enter amount:"))
        if amount > user_info["balance"]:
            print("you have insufficient balance in your account.")
        else:
            user_info["balance"] -= amount
            user_info["transaction_info"].append(f"Sent MK{amount}")
            print(f" you have Successfully sent MK{amount}.\n")

def cash_withdraw():
        print("\n--- Cash Withdraw ---")
        print("1. Cordless Withdraw")
        print("2. Agent Direct Cash Withdrawal")
        choice = input("Choose an option (1/2): ")

        if choice == "1":
                print("1. Generate for Self")
                print("2. Generate for Other")
                option = input("Choose an option (1/2): ")
                if option in ["1", "2"]:
                    input("Enter  the source account: ")
                    input("Enter platform: ")
                    amount = float(input("Enter amount: "))
                    confirm = input("Continue? (yes/no): ")
                    if confirm.lower() == "yes":
                        user_info["balance"] -= amount
                        print("Withdrawal is now  successful!")
                        return True
                    else:
                        print("Transaction has cancelled off.")
                        return False
    
        elif choice == "2":
                source=input("Enter source account: ")
                code=input("Enter agent code: ")
                amount = float(input("Enter amount: "))
                confirm = input("Send? (yes/no): ")
                if confirm.lower() == "yes":
                    user_info["balance"] -= amount
                    print("Withdrawal is now successful!")
                else:
                    print("Transaction has cancelled.")

def payments():
            print("\n--- Payments ---")
            print("1. Utility Bills")
            print("2. Tax Payment")
            print("3. DSTV")
            choice = input("Choose an option (1-3): ")

            amount = float(input("Enter amount: "))
            if amount > user_info["balance"]:
                print(" you have insufficient balance.")
            else:
                user_info["balance"] -= amount
                user_info["transaction_info"].append(f"Paid MK{amount}")
                print(f"Payment of MK{amount} successful!\n")

def loans():
        print("\n--- Loans ---")
        print("1. Loan Application")
        print("2. Loan Repayment")
        print("3. Loan Calculator")
        choice = input("Choose an option (1-3): ")

        if choice == "1":
            input("Select Loan Type (e.g. Pay Day Loan): ")
            amount = float(input("Enter Loan Amount: "))
            print(f"Loan of MK{amount} applied successfully!")

        elif choice == "3":
            amount = float(input("Enter Loan Amount: "))
            rate = float(input("Enter Annual Rate (%): "))
            months = int(input("Enter Loan Period (Months): "))
            monthly_payment = (amount * (rate / 100) / 12) + (amount / months)
            print(f"Estimated Monthly Payment: MK{monthly_payment:}\n")

def my_account():
        print("\n--- My Account ---")
        print("1. Balance Enquiry")
        print("2. Mini Statement")
        print("3. Interim Statement")
        choice = input("Choose an option (1-3): ")

        if choice == "1":
            check_balance()
        elif choice == "2":
            print("\nMini Statement:")
            for transaction in user_info["transaction_info"][-5:]:
                print(transaction)
        elif choice == "3":
            input("Enter source account: ")
            input("Select statement format (PDF/Excel/CSV): ")
            input("Enter date range: ")
            print("Statement generated successfully!\n")

def logout():
        print("You have been logged out.\n")
        return False

def main():
        print("Welcome to the Online Bank System!")
        logged_in = False
        registered = False

        while True:
            if not registered:
                print("\n1. Register")
                print("2. Exit")
                choice = input("Choose an option (1/2): ")

                if choice == "1":
                    registered = True
                    name=input('enter your name:')
                    number=input('enter you number:')
                    email=input('enter your email address:')
                    password=input('enter password to confirm registering:')
                    print('your have successifully registering your account')
                elif choice == "2":
                    print("Exiting the program. Thank you for visting us!")
                    break
                else:
                    print("Invalid choice.")

            elif not logged_in:
                print("\n1. Sign_In")
                print("2. Exit")
                choice = input("Choose an option (1/2): ")

                if choice == "1":
                    sign_in=True
                    name=input('enter your name:')
                    number=input('enter you number:')
                    password=input('enter password to confirm signing in:')
                    print('processes of signing in is succesiflly done!\n')
                    
                elif choice == "2":
                    print("Exiting the program. Thank you for visiting us!")
                    break
                else:
                    print("Invalid option.")

        else:
            print("\n--- Main Menu ---")
            print("1.register")
            print("2.sign_in")
            print("3.check_balance")
            print("4.send_money_To_")
            print("5.cash_withdraw")
            print("6.payments")
            print("7.loans")
            print("8.logout")      
            choice = input("Choose an option (1-7): ")

        if choice == "1":
            register()
        elif choice == "2":
            sign_in()
        elif choice == "3":
            check_balance()
        elif choice == "4":
            send_money_To_()
        elif choice == "5":
            cash_withdraw()
        elif choice == "6":
            payments()
        elif choice == "7":
            loans()
        elif choice == "8":
            logged_in = logout()
            print("Exiting the program!")
        else:
                print("Invalid choice.") 

main()
# Out:
# Welcome to the Online Bank System!
#
# 1. Register
# 2. Exit
# Choose an option (1/2):  1
# enter your name: issa
# enter you number: 0099
# enter your email address: issa..
# enter password to confirm registering: 2020
# your have successifully registering your account
#
# 1. Sign_In
# 2. Exit
# Choose an option (1/2):  1
# enter your name: issa
# enter you number: 0099
# enter password to confirm signing in: 2020
# processes of signing in is succesiflly done!
#
#
# 1. Sign_In
# 2. Exit
